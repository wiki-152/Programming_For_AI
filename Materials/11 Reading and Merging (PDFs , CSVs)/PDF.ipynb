# %%
# !pip install PyPDF2
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\umair\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\umair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\umair\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\umair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\umair\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\umair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\umair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\umair\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\umair\anaconda3\lib\site-packages)
# ...

# %%
def replace_whitespace (string):
    #replace \n and \t with a space
    string = string.replace ("\n", " ").replace ("\t", " ")

    return string

# %%
# It only works on textual data
import PyPDF2

pdfFileObj = open('Experience_Letter (1).pdf', 'rb')
pdfReader = PyPDF2.PdfReader(pdfFileObj)
pages = pdfReader.pages
# pages_text = [clean_text(pages[i].extract_text()) for i in range(len(pages))]
pages_text = [(pages[i].extract_text()) for i in range(len(pages))]
pages_text
# pages_texts = " ".join(pages_text)
# pages_texts = replace_whitespace(pages_texts)
# db = create_substrings(pages_texts)
# ids = [str(i) for i in range(len(pages_texts))]

# %%
pages_texts
# Out:
# 'Experience Letter September 20, 2023 To Whom it May Concern Muhammad Aashir has successfully completed the tenure at the Artificial Intelligence and Machine Learning Lab at the National University of Computer and Emerging Sciences. He was a Machine Learning Researcher at the lab from 20 August 2022 to 1st July 2023. He worked on Multimodal Hate speech Detection for Urdu Language. He excelled in curating a comprehensive Urdu dataset and developing advanced multimodal models for hate speech detection. Furthermore, he implemented cross-modal fusion techniques, such as Late Fusion and Early Fusion, as part of his approach. He has a genuine passion for computation, encompassing the practical and theoretical branches of modern computer science. I have witnessed several examples of his intelligence and have been impressed by his ability to solve complex problems. I wish his success in his future endeavors. Mirza Omer Beg Professor, Department of Computer Science Head, Artificial Intelligen
# ...

# %%
import tabula
import pandas as pd
custom_column_names=["Security Borrower","Foreign Banks","Private Sector Banks","Public Sector Banks","Specialized Banks","All Banks"]

# %%
pdf_file_path = "fil.pdf"
df_list = tabula.read_pdf(pdf_file_path, pages=1)

# %%
df_list
# Out:
# [                                   Security/ Borrower    31-Aug-2023
#  0                                                 NaN  Foreign Banks  \
#  1                             1. FOREIGN CONSTITUENTS            0.0
#  2                            2. DOMESTIC CONSTITUENTS          467.4
#  3                                       I. GOVERNMENT          397.2
#  4   II.  NON-FINANCIAL PUBLIC SECTOR ENTERPRISES (...              -
#  ..                                                ...            ...
#  91                                      a) Indigenous              -
#  92                                        b) Imported              -
#  93                                    9. Sports Goods              -
#  94                           10. Surgical Instruments            0.1
#  95                             11. Chemicals and Dyes            0.0
#
#                 Unnamed: 0           Unnamed: 1         Unnamed: 2 Unnamed: 3
# ...

# %%
combined_df = pd.concat(dfs, ignore_index=True)
combined_df
# Out:
#                                    Security/ Borrower    31-Aug-2023
# 0                                                 NaN  Foreign Banks  \
# 1                             1. FOREIGN CONSTITUENTS            0.0
# 2                            2. DOMESTIC CONSTITUENTS          467.4
# 3                                       I. GOVERNMENT          397.2
# 4   II.  NON-FINANCIAL PUBLIC SECTOR ENTERPRISES (...              -
# ..                                                ...            ...
# 91                                      a) Indigenous              -
# 92                                        b) Imported              -
# 93                                    9. Sports Goods              -
# 94                           10. Surgical Instruments            0.1
# 95                             11. Chemicals and Dyes            0.0
#
#                Unnamed: 0           Unnamed: 1         Unnamed: 2 Unnamed: 3
# ...

# %%
df=combined_df
df.columns=custom_column_names
# df.columns = ['_'.join(col).strip() for col in df.columns.values]
# df.columns = df.columns.str.replace('_', ' ')
df
# Out:
#                                     Security Borrower  Foreign Banks
# 0                                                 NaN  Foreign Banks  \
# 1                             1. FOREIGN CONSTITUENTS            0.0
# 2                            2. DOMESTIC CONSTITUENTS          467.4
# 3                                       I. GOVERNMENT          397.2
# 4   II.  NON-FINANCIAL PUBLIC SECTOR ENTERPRISES (...              -
# ..                                                ...            ...
# 91                                      a) Indigenous              -
# 92                                        b) Imported              -
# 93                                    9. Sports Goods              -
# 94                           10. Surgical Instruments            0.1
# 95                             11. Chemicals and Dyes            0.0
#
#      Private Sector Banks  Public Sector Banks  Specialized Banks  All Banks
# ...

# %%
df = df.drop(0)

# %%
df.to_csv

# %%
df
# Out:
#                                     Security Borrower Foreign Banks
# 1                             1. FOREIGN CONSTITUENTS           0.0  \
# 2                            2. DOMESTIC CONSTITUENTS         467.4
# 3                                       I. GOVERNMENT         397.2
# 4   II.  NON-FINANCIAL PUBLIC SECTOR ENTERPRISES (...             -
# 5        III. NON-BANK FINANCIAL INSTITUTIONS (NBFIs)             -
# ..                                                ...           ...
# 91                                      a) Indigenous             -
# 92                                        b) Imported             -
# 93                                    9. Sports Goods             -
# 94                           10. Surgical Instruments           0.1
# 95                             11. Chemicals and Dyes           0.0
#
#    Private Sector Banks Public Sector Banks Specialized Banks All Banks
# 1                     -                   -                 -       0.0
# ...

# %%
import tabula
import pandas as pd
# custom_column_names=["Security Borrower","Foreign Banks","Private Sector Banks","Public Sector Banks","Specialized Banks","All Banks"]

# %%
pdf_file_path = "20231004151108127552000_1118450_T-BILLS_MATURITY_DUE_ON_05-10-2023.pdf"
df_list = tabula.read_pdf(pdf_file_path, pages=2)

dfs = []
for df in df_list:
    dfs.append(df)

    
combined_df = pd.concat(dfs, ignore_index=True)
combined_df.drop(0)
# df_list
# Out:
# Got stderr: Oct 12, 2023 5:03:07 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (9) in font Helvetica
# Oct 12, 2023 5:03:08 PM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 9 (.notdef) in font Helvetica
#                          Unnamed: 0 Unnamed: 1 Unnamed: 2   Unnamed: 3
# 1                               NaN        NaN        NaN          NaN  \
# 2                     Customer Name     Dealer     Deader   Face vain.
# 3                               NaN       Name      Pilaf          NaN
# 4                               NaN        NaN        NaN          NaN
# 5        ADADAGE INSURANCE CO. LTD.        NaN        NaN          NaN
# 6                               NaN         MO    95.0250   25,000,000
# 7           EMPLOYEES GUI-UFO GINO.        NaN        NaN          NaN
# 8          MARCH INSURANCE CO. LTD.        NaN        NaN          NaN
# ...

# %%
combined_df=combined_df.drop(1)

# %%
combined_df
# Out:
#                          Unnamed: 0 Unnamed: 1 Unnamed: 2   Unnamed: 3
# 0                               NaN   Prfenaty    Primary          NaN  \
# 2                     Customer Name     Dealer     Deader   Face vain.
# 3                               NaN       Name      Pilaf          NaN
# 4                               NaN        NaN        NaN          NaN
# 5        ADADAGE INSURANCE CO. LTD.        NaN        NaN          NaN
# 6                               NaN         MO    95.0250   25,000,000
# 7           EMPLOYEES GUI-UFO GINO.        NaN        NaN          NaN
# 8          MARCH INSURANCE CO. LTD.        NaN        NaN          NaN
# 9                               NaN         MO     950250   140,000E00
# 10         EMPLOYEES PROVIDENT FUND        NaN        NaN          NaN
# 11    AIMMEE UTE ASSURANCE CO. LTD.        NaN        NaN          NaN
# 12                              NaN  HA618METP    95.0254  617,000,000
# ...

# %%
import pandas as pd

# %%
re
